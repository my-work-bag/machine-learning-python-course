# %% [markdown]
# #Modelos de Classificação: Random Forest

# %% [markdown]
# ### Importando libs  e funções

# %% [markdown]
# Importando libs

# %%
import pandas as pd
from sklearn.model_selection import cross_validate
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Etapa de exploração e tratamento dos dados

# %% [markdown]
# Esse conjunto de dados é composto por uma série de medidas biomédicas de 31 pacientes, sendo 23 com doença de Parkinson (DP). Cada coluna  é uma medida de voz específica e cada linha corresponde a uma das 195 gravações de voz desses indivíduos. O principal objetivo dos dados é discriminar pessoas saudáveis daquelas com Parkinson de acordo com a coluna "status", que é definida como 0 para saudável e 1 para DP.
#
# Mais informações a respeito do dataset: [UCL](https://archive.ics.uci.edu/ml/datasets/Parkinsons)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/intelligentagents/aprendizagem-supervisionada/master/data/parkinsons.csv')

# %% [markdown]
# Descrevendo o dataset

# %%
# Exporando o dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
# name                195 non-null object
# MDVP:Fo(Hz)         195 non-null float64
# MDVP:Fhi(Hz)        195 non-null float64
# MDVP:Flo(Hz)        195 non-null float64
# MDVP:Jitter(%)      195 non-null float64
# MDVP:Jitter(Abs)    195 non-null float64
# MDVP:RAP            195 non-null float64
# MDVP:PPQ            195 non-null float64
# Jitter:DDP          195 non-null float64
# MDVP:Shimmer        195 non-null float64
# MDVP:Shimmer(dB)    195 non-null float64
# Shimmer:APQ3        195 non-null float64
# Shimmer:APQ5        195 non-null float64
# MDVP:APQ            195 non-null float64
# Shimmer:DDA         195 non-null float64
# NHR                 195 non-null float64
# HNR                 195 non-null float64
# status              195 non-null int64
# RPDE                195 non-null float64
# DFA                 195 non-null float64
# ...

# %%
# Visualizando o sumário das colunas numéricas do dataset
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  ...          D2         PPE
# count   195.000000    195.000000  ...  195.000000  195.000000
# mean    154.228641    197.104918  ...    2.381826    0.206552
# std      41.390065     91.491548  ...    0.382799    0.090119
# min      88.333000    102.145000  ...    1.423287    0.044539
# 25%     117.572000    134.862500  ...    2.099125    0.137451
# 50%     148.790000    175.829000  ...    2.361532    0.194052
# 75%     182.769000    224.205500  ...    2.636456    0.252980
# max     260.105000    592.030000  ...    3.671155    0.527367
#
# [8 rows x 23 columns]

# %% [markdown]
# Visualizando o dataset

# %%
df.head(5)
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  ...   spread2        D2       PPE
# 0  phon_R01_S01_1      119.992       157.302  ...  0.266482  2.301442  0.284654
# 1  phon_R01_S01_2      122.400       148.650  ...  0.335590  2.486855  0.368674
# 2  phon_R01_S01_3      116.682       131.111  ...  0.311173  2.342259  0.332634
# 3  phon_R01_S01_4      116.676       137.871  ...  0.334147  2.405554  0.368975
# 4  phon_R01_S01_5      116.014       141.781  ...  0.234513  2.332180  0.410335
#
# [5 rows x 24 columns]

# %% [markdown]
# Retirando a coluna com o nome do dataframe:

# %%
df = df.drop(['name'], axis=1)

# %% [markdown]
# Definindo as variáveis dependentes/independentes:

# %%
X = df[df.columns[~df.columns.isin(['status'])]].values
y = df['status'].values

# %% [markdown]
# ### Etapa de Treinamento e Avaliação do Modelo

# %% [markdown]
# Definindo as métricas a serem utilizadas:

# %%
metrics = ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro']

# %% [markdown]
# Treinando o modelo de Classificação usando a validação cruzada com 10 folds:

# %%
classifier = RandomForestClassifier(criterion = 'entropy', random_state = 0, n_estimators = 10)

scores = cross_validate(classifier, X, y, cv=10, scoring=metrics)

# %% [markdown]
# Visualizando os resultados:

# %%
pd.DataFrame.from_dict(scores)
# Out:
#    fit_time  score_time  ...  test_recall_macro  test_f1_macro
# 0  0.018110    0.006447  ...           0.833333       0.811912
# 1  0.016149    0.006003  ...           0.900000       0.829060
# 2  0.015378    0.006087  ...           0.800000       0.843750
# 3  0.015514    0.006253  ...           0.866667       0.866667
# 4  0.015754    0.005906  ...           1.000000       1.000000
# 5  0.015455    0.006060  ...           0.766667       0.715100
# 6  0.016246    0.006199  ...           0.433333       0.393939
# 7  0.016191    0.006046  ...           0.528571       0.525000
# 8  0.015849    0.006232  ...           0.553571       0.556650
# 9  0.015968    0.006204  ...           0.750000       0.800000
#
# [10 rows x 6 columns]

# %% [markdown]
# Exibindo os valores da media das métricas:

# %%
pd.DataFrame.from_dict(scores).mean()
# Out:
# fit_time                0.016061
# score_time              0.006144
# test_accuracy           0.819532
# test_precision_macro    0.753324
# test_recall_macro       0.743214
# test_f1_macro           0.734208
# dtype: float64
